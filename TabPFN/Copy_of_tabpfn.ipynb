# %%
## Base library Installation
# Install Baselines for model comparison
# !uv pip install catboost xgboost

# Install the datasets library for loading example data
# !uv pip install datasets

# Install rich for better and more readable printing
# !uv pip install rich


## TabPFN Installation optimized for Google Colab
# Install the TabPFN Client library
# !uv pip install tabpfn-client

# Install tabpfn from source
# Clone the repository: shallow for speedup
# !git clone --depth 1 https://github.com/PriorLabs/tabpfn

# Speeding up installation in this notebook:
# Remove torch dependency as it is already installed on colab (do not run this in your local setup)
# !sed -i "/torch/d" tabpfn/pyproject.toml

# Step 3: Install using the correct directory name 'tabpfn'
# !uv pip install -e "tabpfn"

# Install TabPFN extensions for additional functionalities
# !git clone https://github.com/PriorLabs/tabpfn-extensions

# Speeding up installation in this notebook:
# Remove torch dependency as it is already installed on colab (do not run this in your local setup)
# !sed -i "/torch/d" tabpfn-extensions/pyproject.toml

# !uv pip install -e tabpfn-extensions[all]
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 21 packages in 493ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)
# ⠼ Preparing packages... (0/1)
# ⠼ Preparing packages... (0/1)
# ⠼ Preparing packages... (0/1)
# ⠴ Preparing packages... (0/1)
# ⠴ Preparing packages... (0/1)
# ⠴ Preparing packages... (0/1)
# ⠴ Preparing packages... (0/1)
# ⠴ Preparing packages... (0/1)
# ⠦ Preparing packages... (0/1)
# ⠦ Preparing packages... (0/1)
# ⠦ Preparing packages... (0/1)
# ⠦ Preparing packages... (0/1)
# ⠧ Preparing packages... (0/1)
# ⠧ Preparing packages... (0/1)
# ⠧ Preparing packages... (0/1)
# ⠧ Preparing packages... (0/1)
# ⠇ Preparing packages... (0/1)
# ⠇ Preparing packages... (0/1)
# ⠇ Preparing packages... (0/1)
# ⠇ Preparing packages... (0/1)
# ⠋ Preparing packages... (0/1)
# ⠋ Preparing packages... (0/1)
# ⠋ Preparing packages... (0/1)
# ⠋ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)
# Prepared 1 package in 2.11s
# Installed 1 package in 8ms
#  + catboost==1.2.8
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 226ms
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 171ms
# Using Python 3.11.13 environment at: /usr
# Resolved 26 packages in 302ms
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# sseclient-py ------------------------------ 8.62 KiB/8.62 KiB
# ⠙ Preparing packages... (0/3)
# sseclient-py ------------------------------ 8.62 KiB/8.62 KiB
# ⠙ Preparing packages... (0/3)
# sseclient-py ------------------------------ 8.62 KiB/8.62 KiB
# password-strength ------------------------------ 11.88 KiB/11.88 KiB
# ⠙ Preparing packages... (0/3)
# sseclient-py ------------------------------ 8.62 KiB/8.62 KiB
# password-strength ------------------------------ 11.88 KiB/11.88 KiB
# ⠙ Preparing packages... (0/3)
# password-strength ------------------------------ 11.88 KiB/11.88 KiB
# ⠙ Preparing packages... (0/3)
# password-strength ------------------------------ 11.88 KiB/11.88 KiB
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠹ Preparing packages... (2/3)
# Prepared 3 packages in 225ms
# Installed 3 packages in 23ms
#  + password-strength==0.0.3.post2
#  + sseclient-py==1.8.0
#  + tabpfn-client==0.1.10
# Cloning into 'tabpfn'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 108 (delta 9), reused 56 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 1.46 MiB | 6.36 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# Using Python 3.11.13 environment at: /usr
# Resolved 32 packages in 381ms
#    Building tabpfn @ file:///content/tabpfn
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 14.88 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠋ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 14.88 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 14.88 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 14.88 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 14.88 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
# eval-type-backport ------------------------------ 5.69 KiB/5.69 KiB
# python-dotenv ------------------------------ 20.07 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
# python-dotenv ------------------------------ 20.07 KiB/20.07 KiB
#    Building tabpfn @ file:///content/tabpfn
# ⠙ Preparing packages... (0/4)
#    Building tabpfn @ file:///content/tabpfn
#    Building tabpfn @ file:///content/tabpfn
#    Building tabpfn @ file:///content/tabpfn
#    Building tabpfn @ file:///content/tabpfn
#    Building tabpfn @ file:///content/tabpfn
#       Built tabpfn @ file:///content/tabpfn
# Prepared 4 packages in 884ms
# Installed 4 packages in 2ms
#  + eval-type-backport==0.2.2
#  + pydantic-settings==2.10.1
#  + python-dotenv==1.1.1
#  + tabpfn==2.1.2 (from file:///content/tabpfn)
# Cloning into 'tabpfn-extensions'...
# remote: Enumerating objects: 2881, done.
# remote: Counting objects: 100% (884/884), done.
# remote: Compressing objects: 100% (291/291), done.
# remote: Total 2881 (delta 729), reused 595 (delta 582), pack-reused 1997 (from 1)
# Receiving objects: 100% (2881/2881), 922.31 KiB | 17.40 MiB/s, done.
# Resolving deltas: 100% (1791/1791), done.
# Using Python 3.11.13 environment at: /usr
# Resolved 65 packages in 353ms
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 16.00 KiB/19.78 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 16.00 KiB/19.78 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 19.78 KiB/19.78 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 19.78 KiB/19.78 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 19.78 KiB/19.78 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# jmespath   ------------------------------ 19.78 KiB/19.78 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------     0 B/26.40 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------     0 B/26.40 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# shapiq     ------------------------------     0 B/277.62 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------     0 B/26.40 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# autogluon-core ------------------------------     0 B/219.81 KiB
# shapiq     ------------------------------     0 B/277.62 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------     0 B/26.40 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# autogluon-common ------------------------------     0 B/69.33 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# autogluon-core ------------------------------     0 B/219.81 KiB
# shapiq     ------------------------------     0 B/277.62 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------     0 B/26.40 KiB
# autogluon-features ------------------------------ 30.87 KiB/62.69 KiB
# autogluon-common ------------------------------     0 B/69.33 KiB
# s3transfer ------------------------------     0 B/83.31 KiB
# boto3      ------------------------------     0 B/136.79 KiB
# autogluon-core ------------------------------     0 B/219.81 KiB
# shapiq     ------------------------------     0 B/277.62 KiB
# autogluon-tabular ------------------------------ 14.90 KiB/475.83 KiB
# galois     ------------------------------     0 B/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# sparse-transform ------------------------------ 26.40 KiB/26.40 KiB
# autogluon-common ------------------------------ 30.91 KiB/69.33 KiB
# s3transfer ------------------------------ 78.88 KiB/83.31 KiB
# boto3      ------------------------------ 14.88 KiB/136.79 KiB
# autogluon-core ------------------------------ 14.91 KiB/219.81 KiB
# shapiq     ------------------------------ 32.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 30.90 KiB/475.83 KiB
# galois     ------------------------------ 48.48 KiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-common ------------------------------ 30.91 KiB/69.33 KiB
# s3transfer ------------------------------ 78.88 KiB/83.31 KiB
# boto3      ------------------------------ 14.88 KiB/136.79 KiB
# autogluon-core ------------------------------ 14.91 KiB/219.81 KiB
# shapiq     ------------------------------ 32.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 30.90 KiB/475.83 KiB
# galois     ------------------------------ 48.48 KiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-common ------------------------------ 30.91 KiB/69.33 KiB
# s3transfer ------------------------------ 83.31 KiB/83.31 KiB
# boto3      ------------------------------ 30.88 KiB/136.79 KiB
# autogluon-core ------------------------------ 14.91 KiB/219.81 KiB
# shapiq     ------------------------------ 48.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 78.90 KiB/475.83 KiB
# galois     ------------------------------ 64.48 KiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-common ------------------------------ 30.91 KiB/69.33 KiB
# boto3      ------------------------------ 46.88 KiB/136.79 KiB
# autogluon-core ------------------------------ 14.91 KiB/219.81 KiB
# shapiq     ------------------------------ 48.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 78.90 KiB/475.83 KiB
# galois     ------------------------------ 64.48 KiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-common ------------------------------ 46.91 KiB/69.33 KiB
# boto3      ------------------------------ 62.88 KiB/136.79 KiB
# autogluon-core ------------------------------ 30.91 KiB/219.81 KiB
# shapiq     ------------------------------ 48.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 78.90 KiB/475.83 KiB
# galois     ------------------------------ 2.05 MiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-common ------------------------------ 62.91 KiB/69.33 KiB
# boto3      ------------------------------ 75.06 KiB/136.79 KiB
# autogluon-core ------------------------------ 78.91 KiB/219.81 KiB
# shapiq     ------------------------------ 97.53 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 116.28 KiB/475.83 KiB
# galois     ------------------------------ 3.94 MiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# boto3      ------------------------------ 91.06 KiB/136.79 KiB
# autogluon-core ------------------------------ 94.91 KiB/219.81 KiB
# shapiq     ------------------------------ 97.53 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 132.99 KiB/475.83 KiB
# galois     ------------------------------ 3.96 MiB/3.98 MiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# boto3      ------------------------------ 136.79 KiB/136.79 KiB
# autogluon-core ------------------------------ 142.80 KiB/219.81 KiB
# shapiq     ------------------------------ 160.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 142.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-core ------------------------------ 158.91 KiB/219.81 KiB
# shapiq     ------------------------------ 160.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 142.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# shapiq     ------------------------------ 224.00 KiB/277.62 KiB
# autogluon-tabular ------------------------------ 194.59 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-tabular ------------------------------ 206.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠙ Preparing packages... (0/12)
# autogluon-tabular ------------------------------ 254.90 KiB/475.83 KiB
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠹ Preparing packages... (9/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠹ Preparing packages... (9/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠹ Preparing packages... (9/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠹ Preparing packages... (9/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠹ Preparing packages... (9/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
# ⠸ Preparing packages... (10/12)
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
#    Building tabpfn-extensions @ file:///content/tabpfn-extensions
#       Built tabpfn-extensions @ file:///content/tabpfn-extensions
# Prepared 12 packages in 919ms
# Installed 12 packages in 69ms
#  + autogluon-common==1.4.0
#  + autogluon-core==1.4.0
#  + autogluon-features==1.4.0
#  + autogluon-tabular==1.4.0
#  + boto3==1.40.12
#  + botocore==1.40.12
#  + galois==0.4.6
#  + jmespath==1.0.1
#  + s3transfer==0.13.1
#  + shapiq==1.3.1
#  + sparse-transform==0.2.1
#  + tabpfn-extensions==0.1.3 (from file:///content/tabpfn-extensions)

# %%
import tabpfn
print("TabPFN imported successfully!")
# Out:
# TabPFN imported successfully!

# %%
# Standard Library Imports

# TabPFN and Extensions

try:
    from tabpfn import TabPFNClassifier, TabPFNRegressor
    from tabpfn_extensions.post_hoc_ensembles.sklearn_interface import (
        AutoTabPFNClassifier,
    )
except ImportError:
    raise ImportError(
        "Warning: Could not import TabPFN / TabPFN extensions. Please run installation above and restart the session afterwards (Runtime > Restart Session)."
    )

# Data Science & Visualization
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

# Other ML Models
from catboost import CatBoostClassifier, CatBoostRegressor

# Notebook UI/Display
from IPython.display import Markdown, display
from rich.console import Console
from rich.panel import Panel
from rich.prompt import Prompt
from rich.rule import Rule
from sklearn.compose import make_column_selector, make_column_transformer

# Scikit-Learn: Data & Preprocessing
from sklearn.datasets import fetch_openml, load_breast_cancer

# Scikit-Learn: Models
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.model_selection import (
    KFold,
    StratifiedKFold,
    cross_val_score,
    train_test_split,
)
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from xgboost import XGBClassifier, XGBRegressor

# This transformer will be used to handle categorical features for the baseline models
column_transformer = make_column_transformer(
    (
        OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
        make_column_selector(dtype_include=["object", "category"]),
    ),
    remainder="passthrough",
)

# %%
from sklearn.utils import shuffle
from pathlib import Path

# %%
def split_data(X, Y, p = 0.8, seed = 123456):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = p, random_state = seed)
    return X_train, X_test, Y_train, Y_test

# %%
def performance_eval(Y_pred, Y_test):
    Y_pred = np.array(Y_pred)
    Y_test = np.array(Y_test)
    MAE = np.mean(np.abs(Y_pred - Y_test))
    RMSE = np.sqrt(np.mean((Y_pred - Y_test)**2))
    MAPE = np.mean(np.abs(Y_test - Y_pred) / ((np.abs(Y_test) + np.abs(Y_pred)) / 2)) * 100

    #accuracy = np.mean(Y_pred == Y_test) * 100

    return MAE, RMSE, MAPE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Base

# %% [markdown]
# ICL4000

# %%
# Set up the data directory path
DATA_DIR = Path("/content/drive/My Drive/tabPFN_data/linear_exp_all_positive2")

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_base.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_base.csv")

# %%
df
# Out:
#                                                    csv       mae      rmse  \
# 0    /content/drive/My Drive/tabPFN_data/linear_exp...  0.116431  0.389478
# 1    /content/drive/My Drive/tabPFN_data/linear_exp...  0.104303  0.130838
# 2    /content/drive/My Drive/tabPFN_data/linear_exp...  0.102707  0.134133
# 3    /content/drive/My Drive/tabPFN_data/linear_exp...  0.086523  0.118739
# 4    /content/drive/My Drive/tabPFN_data/linear_exp...  0.088582  0.112392
# ..                                                 ...       ...       ...
# 995  /content/drive/My Drive/tabPFN_data/linear_exp...  0.093152  0.115417
# 996  /content/drive/My Drive/tabPFN_data/linear_exp...  0.093385  0.127502
# 997  /content/drive/My Drive/tabPFN_data/linear_exp...  0.081944  0.107539
# 998  /content/drive/My Drive/tabPFN_data/linear_exp...  0.098313  0.124965
# 999  /content/drive/My Drive/tabPFN_data/linear_exp...  0.092224  0.128167
#
#          mape
# 0    2.143777
# 1    2.308963
# 2    2.119487
# 3    2.260998
# 4    3.500569
# ..        ...
# 995  2.969915
# 996  2.368307
# 997  2.015369
# 998  2.268969
# 999  2.209483
#
# [1000 rows x 4 columns]

# %%
df = pd.read_csv(DATA_DIR / "results_rowOrder_fewshot10.csv")
df["mae"][:100].describe()
# Out:
# count    100.000000
# mean       1.111948
# std        0.307509
# min        0.422090
# 25%        0.911799
# 50%        1.112821
# 75%        1.281054
# max        2.482564
# Name: mae, dtype: float64

# %% [markdown]
# ICL10

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:10,:]
    Y_train = Y_train[:10]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_base_fewshot10.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_base_fewshot10.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL20

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:20,:]
    Y_train = Y_train[:20]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_base_fewshot20.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_base_fewshot20.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL500

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:500,:]
    Y_train = Y_train[:500]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_base_fewshot500.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_base_fewshot500.csv")

# %% [markdown]
# ## Row Order

# %% [markdown]
# ICL4000

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train, Y_train = shuffle(X_train, Y_train, random_state=123456)

    model_row = TabPFNRegressor(random_state=123456)
    model_row.fit(X_train, Y_train)
    y_pred = model_row.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_rowOrder.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_rowOrder.csv")

# %%
df
# Out:
#                                                    csv       mae      rmse  \
# 0    /content/drive/My Drive/tabPFN_data/linear_exp...  0.116028  0.385564
# 1    /content/drive/My Drive/tabPFN_data/linear_exp...  0.105003  0.132267
# 2    /content/drive/My Drive/tabPFN_data/linear_exp...  0.102337  0.133577
# 3    /content/drive/My Drive/tabPFN_data/linear_exp...  0.086595  0.118547
# 4    /content/drive/My Drive/tabPFN_data/linear_exp...  0.088973  0.112360
# ..                                                 ...       ...       ...
# 995  /content/drive/My Drive/tabPFN_data/linear_exp...  0.092295  0.114690
# 996  /content/drive/My Drive/tabPFN_data/linear_exp...  0.093109  0.128055
# 997  /content/drive/My Drive/tabPFN_data/linear_exp...  0.083323  0.108347
# 998  /content/drive/My Drive/tabPFN_data/linear_exp...  0.098438  0.125333
# 999  /content/drive/My Drive/tabPFN_data/linear_exp...  0.092111  0.128016
#
#          mape
# 0    2.142260
# 1    2.332470
# 2    2.115820
# 3    2.265478
# 4    3.504979
# ..        ...
# 995  2.957135
# 996  2.359052
# 997  2.035877
# 998  2.276191
# 999  2.206486
#
# [1000 rows x 4 columns]

# %% [markdown]
# ICL10

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:10,:]
    Y_train = Y_train[:10]
    X_train, Y_train = shuffle(X_train, Y_train, random_state=123456)

    model_row = TabPFNRegressor(random_state=123456)
    model_row.fit(X_train, Y_train)
    y_pred = model_row.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_rowOrder_fewshot10.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_rowOrder_fewshot10.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL20

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:20,:]
    Y_train = Y_train[:20]
    X_train, Y_train = shuffle(X_train, Y_train, random_state=123456)

    model_row = TabPFNRegressor(random_state=123456)
    model_row.fit(X_train, Y_train)
    y_pred = model_row.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_rowOrder_fewshot20_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_rowOrder_fewshot20_100.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL500

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:500,:]
    Y_train = Y_train[:500]
    X_train, Y_train = shuffle(X_train, Y_train, random_state=123456)

    model_row = TabPFNRegressor(random_state=123456)
    model_row.fit(X_train, Y_train)
    y_pred = model_row.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_rowOrder_fewshot500_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_rowOrder_fewshot500_100.csv")

# %% [markdown]
# ## Num_Digits

# %% [markdown]
# ICL4000

# %%
DATA_DIR = Path("/content/drive/My Drive/tabPFN_data/linear_exp_all_positive2_10_digits")

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_10_digits.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_10_digits.csv")

# %% [markdown]
# ICL10

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:10,:]
    Y_train = Y_train[:10]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_10_digits_fewshot10_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_10_digits_fewshot10_100.csv")

# %% [markdown]
# ICL20

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:20,:]
    Y_train = Y_train[:20]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_10_digits_fewshot20_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_10_digits_fewshot20_100.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL500

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:500,:]
    Y_train = Y_train[:500]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_10_digits_fewshot500_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_10_digits_fewshot500_100.csv")

# %% [markdown]
# ## Column_Order

# %% [markdown]
# ICL4000

# %%
DATA_DIR = Path("/content/drive/My Drive/tabPFN_data/linear_exp_all_positive2_shuffle")

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:1000]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_shuffle.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_shuffle.csv")

# %% [markdown]
# ICL10

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:10,:]
    Y_train = Y_train[:10]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_shuffle_fewshot10_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_shuffle_fewshot10_100.csv")

# %% [markdown]
# ICL20

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:20,:]
    Y_train = Y_train[:20]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_shuffle_fewshot20_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_shuffle_fewshot20_100.csv")
# Out:
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)
# /content/tabpfn/src/tabpfn/architectures/base/preprocessing.py:315: RuntimeWarning: overflow encountered in cast
#   x_inv[pos] = np.expm1(np.log(x[pos] * lmbda + 1) / lmbda)

# %% [markdown]
# ICL500

# %%
from pathlib import Path
#DATA_DIR = Path("Tabpfn_data/linear_exp_all_positive2")


rows = []
files = sorted(DATA_DIR.glob("dataset_*.csv"))[:100]
for csv_path in files:
#for csv_path in sorted(DATA_DIR.glob("dataset_*.csv")):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=["Y"])
    Y = df["Y"]
    X_train, X_test, Y_train, Y_test = split_data(X, Y)
    X_train = X_train.iloc[:500,:]
    Y_train = Y_train[:500]

    model = TabPFNRegressor(random_state=123456)
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)

    MAE, RMSE, MAPE = performance_eval(y_pred, Y_test)

    rows.append({"csv": str(csv_path), "mae": MAE, "rmse": RMSE, "mape": MAPE})

df = pd.DataFrame(rows)
df.to_csv(DATA_DIR / "results_shuffle_fewshot500_100.csv", index=False)
df[["mae", "rmse", "mape"]].describe().to_csv(DATA_DIR / "summary_statistics_shuffle_fewshot500_100.csv")
